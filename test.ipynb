# %%
from keras.models import load_model
from time import sleep
from keras.preprocessing.image import img_to_array
from keras.preprocessing import image
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
classifier = load_model('./Emotion_Detection.h5')

class_labels = ['Angry', 'Happy', 'Neutral', 'Sad', 'Surprise']

cap = cv2.VideoCapture(0)

while True:
    # Grab a single frame of video
    ret, frame = cap.read()
    labels = []
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
        roi_gray = gray[y:y + h, x:x + w]
        roi_gray = cv2.resize(roi_gray, (48, 48), interpolation=cv2.INTER_AREA)

        if np.sum([roi_gray]) != 0:
            roi = roi_gray.astype('float') / 255.0
            roi = img_to_array(roi)
            roi = np.expand_dims(roi, axis=0)

            # make a prediction on the ROI, then lookup the class

            preds = classifier.predict(roi)[0]
            print("\nprediction = ", preds)
            label = class_labels[preds.argmax()]
            print("\nprediction max = ", preds.argmax())
            print("\nlabel = ", label)
            label_position = (x, y)
            cv2.putText(frame, label, label_position, cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 0), 3)
        else:
            cv2.putText(frame, 'No Face Found', (20, 60), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 0), 3)
        print("\n\n")
    cv2.imshow('Emotion Detector', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 1s/step
#
# prediction =  [0.05707428 0.02164831 0.7949752  0.09421631 0.03208589]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 59ms/step
#
# prediction =  [0.04976741 0.01639561 0.8284774  0.07751392 0.02784558]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 76ms/step
#
# prediction =  [0.05599702 0.03176383 0.77728415 0.09200484 0.04295019]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 49ms/step
#
# prediction =  [0.08304363 0.03422752 0.6843528  0.14940825 0.04896778]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 44ms/step
#
# prediction =  [0.07878906 0.05944588 0.6518911  0.13792221 0.07195175]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 54ms/step
#
# prediction =  [0.05860692 0.03750543 0.7872221  0.09412035 0.02254524]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 45ms/step
#
# prediction =  [0.04001147 0.01521073 0.8736399  0.06189402 0.00924387]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 54ms/step
#
# prediction =  [0.03953856 0.01948503 0.8666831  0.06258642 0.01170678]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 58ms/step
#
# prediction =  [0.05057039 0.01579015 0.83528775 0.08067603 0.01767568]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 48ms/step
#
# prediction =  [0.04084144 0.02423734 0.8582871  0.06071915 0.01591497]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 56ms/step
#
# prediction =  [0.04674748 0.03022517 0.8283115  0.06922808 0.02548776]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 40ms/step
#
# prediction =  [0.06445442 0.03791415 0.75280625 0.10970316 0.03512206]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 45ms/step
#
# prediction =  [0.05689274 0.0319106  0.76801974 0.09438256 0.04879436]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.05027063 0.02983643 0.8010024  0.08012438 0.03876615]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 42ms/step
#
# prediction =  [0.05407626 0.02979446 0.77975845 0.08779907 0.04857173]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.06081679 0.03012065 0.7208478  0.10027055 0.0879442 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 58ms/step
#
# prediction =  [0.08716223 0.03881638 0.63250184 0.14054081 0.10097872]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 57ms/step
#
# prediction =  [0.08058564 0.02813813 0.6610096  0.12566154 0.10460504]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 51ms/step
#
# prediction =  [0.08449512 0.01946791 0.6927474  0.13518317 0.06810639]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 61ms/step
#
# prediction =  [0.07908303 0.02090507 0.7024338  0.13085228 0.06672581]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 45ms/step
#
# prediction =  [0.07280604 0.02451576 0.6746659  0.12108406 0.10692818]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 52ms/step
#
# prediction =  [0.06832739 0.02667021 0.7034902  0.11568084 0.08583143]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 65ms/step
#
# prediction =  [0.07307016 0.02228066 0.676816   0.11639386 0.11143931]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 43ms/step
#
# prediction =  [0.07005663 0.0172463  0.7333557  0.11368982 0.06565159]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 40ms/step
#
# prediction =  [0.04186462 0.16331431 0.6359163  0.06727406 0.09163076]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 50ms/step
#
# prediction =  [0.04012767 0.53249854 0.30001757 0.06577829 0.06157799]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 42ms/step
#
# prediction =  [0.01451857 0.83466053 0.1017921  0.0226769  0.02635193]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.03229835 0.65616447 0.22572657 0.05894199 0.02686864]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 47ms/step
#
# prediction =  [0.02300598 0.6298378  0.2698559  0.04172423 0.03557606]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 40ms/step
#
# prediction =  [0.01740262 0.7942445  0.12902556 0.02738799 0.03193935]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.03763522 0.5122931  0.34094396 0.07013111 0.03899654]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 51ms/step
#
# prediction =  [0.02455733 0.69609785 0.2065658  0.04096442 0.03181462]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 55ms/step
#
# prediction =  [0.02969949 0.6052554  0.25973707 0.05070515 0.05460289]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 53ms/step
#
# prediction =  [0.13110487 0.05036105 0.5576304  0.21264192 0.04826169]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 49ms/step
#
# prediction =  [0.07215618 0.04397829 0.69541943 0.12237813 0.06606801]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.10059085 0.05270737 0.6365387  0.16168736 0.04847572]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 49ms/step
#
# prediction =  [0.08055082 0.03371527 0.72666293 0.12668453 0.03238642]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.07197997 0.03170181 0.7578816  0.11057577 0.02786088]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 58ms/step
#
# prediction =  [0.08005366 0.0284889  0.73283565 0.12473036 0.03389136]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 52ms/step
#
# prediction =  [0.05848243 0.01892725 0.8141894  0.0907411  0.01765977]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 59ms/step
#
# prediction =  [0.06963477 0.01470985 0.78868395 0.11011799 0.01685346]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 60ms/step
#
# prediction =  [0.06482505 0.02073628 0.79313934 0.10054439 0.02075497]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 48ms/step
#
# prediction =  [0.06867875 0.03140551 0.7672269  0.10749812 0.02519071]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 39ms/step
#
# prediction =  [0.06712218 0.02845654 0.775118   0.10544899 0.02385434]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.05801872 0.03296649 0.8004295  0.08880588 0.01977932]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 40ms/step
#
# prediction =  [0.07678418 0.03722703 0.71626425 0.12179144 0.0479332 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 41ms/step
#
# prediction =  [0.06828121 0.04022468 0.7214943  0.10883831 0.06116151]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 56ms/step
#
# prediction =  [0.08106555 0.07358526 0.6045445  0.12435506 0.11644951]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 50ms/step
#
# prediction =  [0.07878418 0.03281515 0.7033385  0.12425305 0.06080905]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 55ms/step
#
# prediction =  [0.07093501 0.02795199 0.73365456 0.10775647 0.05970197]
#
# prediction max =  2
#
# label =  Neutral
# 1/1 [==============================] - 0s 64ms/step
#
# prediction =  [0.08403783 0.02342363 0.6954884  0.12885351 0.06819671]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.073776   0.02076111 0.75062793 0.11144713 0.04338784]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 53ms/step
#
# prediction =  [0.05416341 0.01728759 0.8291428  0.07968497 0.01972122]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.06323283 0.02363176 0.77832514 0.09571029 0.03909992]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 51ms/step
#
# prediction =  [0.10101592 0.05100756 0.5134215  0.1527131  0.18184197]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 59ms/step
#
# prediction =  [0.10373501 0.04980956 0.6201751  0.17588776 0.05039248]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 40ms/step
#
# prediction =  [0.0801935  0.02085583 0.7424864  0.13374841 0.02271578]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 43ms/step
#
# prediction =  [0.07972491 0.01572642 0.75693077 0.13384174 0.01377614]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.10549928 0.04878835 0.638356   0.1778448  0.02951164]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 48ms/step
#
# prediction =  [0.07139535 0.03622439 0.75438046 0.118408   0.0195918 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.06009131 0.02551483 0.79770666 0.09926654 0.0174208 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 48ms/step
#
# prediction =  [0.1593768  0.14824508 0.25021937 0.4164723  0.02568644]
#
# prediction max =  3
#
# label =  Sad
#
#
#
# 1/1 [==============================] - 0s 45ms/step
#
# prediction =  [0.13243505 0.0820099  0.5125158  0.24912363 0.0239157 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 58ms/step
#
# prediction =  [0.09425703 0.04299847 0.67597955 0.16373402 0.02303096]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 54ms/step
#
# prediction =  [0.07307323 0.02027722 0.7683375  0.12083963 0.01747246]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 47ms/step
#
# prediction =  [0.06288733 0.01931466 0.7997393  0.1006036  0.01745518]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.06219489 0.01435727 0.80993056 0.09997311 0.01354408]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 47ms/step
#
# prediction =  [0.09172314 0.02689935 0.697146   0.16205937 0.02217207]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 41ms/step
#
# prediction =  [0.13568437 0.02756845 0.58538914 0.21181095 0.03954713]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.18068132 0.13601142 0.27877316 0.37484044 0.02969368]
#
# prediction max =  3
#
# label =  Sad
#
#
#
# 1/1 [==============================] - 0s 38ms/step
#
# prediction =  [0.18175334 0.12333195 0.31338775 0.34848455 0.03304239]
#
# prediction max =  3
#
# label =  Sad
#
#
#
# 1/1 [==============================] - 0s 58ms/step
#
# prediction =  [0.12060083 0.05096629 0.5622532  0.19426548 0.0719142 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 57ms/step
#
# prediction =  [0.09259255 0.02730507 0.69396436 0.15391423 0.03222385]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 43ms/step
#
# prediction =  [0.098074   0.02486053 0.66945964 0.17637105 0.03123469]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 59ms/step
#
# prediction =  [0.09163641 0.02742403 0.6990684  0.15662605 0.02524504]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 54ms/step
#
# prediction =  [0.11364289 0.03807611 0.6161258  0.19513488 0.03702033]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.09755159 0.06311556 0.5996065  0.1571214  0.08260488]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 56ms/step
#
# prediction =  [0.10233653 0.05683716 0.5568354  0.16636404 0.11762688]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 61ms/step
#
# prediction =  [0.09420142 0.04366259 0.61033875 0.15559742 0.09619982]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 38ms/step
#
# prediction =  [0.1354609  0.04713329 0.53826606 0.25379398 0.02534575]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 43ms/step
#
# prediction =  [0.07677859 0.02299969 0.75218135 0.12591693 0.02212339]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 53ms/step
#
# prediction =  [0.07432281 0.01789234 0.76602477 0.12582238 0.01593757]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 43ms/step
#
# prediction =  [0.06137611 0.01459756 0.8137261  0.09665515 0.01364508]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.06310213 0.01601216 0.8022161  0.10157721 0.0170923 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.06021887 0.0162164  0.8094383  0.09693414 0.01719226]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 40ms/step
#
# prediction =  [0.04922992 0.01729314 0.8408784  0.07722925 0.01536927]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 59ms/step
#
# prediction =  [0.0624894  0.01763667 0.79841673 0.10149027 0.01996689]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 61ms/step
#
# prediction =  [0.07371174 0.01679526 0.761499   0.11839549 0.02959858]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.058088   0.02030343 0.8044764  0.09182648 0.02530572]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.10036719 0.03934588 0.63874626 0.1777665  0.04377416]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 55ms/step
#
# prediction =  [0.07555968 0.03742772 0.7355771  0.1229937  0.02844173]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 46ms/step
#
# prediction =  [0.08451777 0.02561162 0.7246776  0.14060481 0.02458822]
#
# prediction max =  2
#
# label =  Neutral
